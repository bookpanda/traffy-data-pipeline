# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine("postgresql://root:password@localhost:5432/pipeline_db")
query = "SELECT * FROM processed_data"

df = pd.read_sql(query, engine)

# %%
df
# Out:
#         ticket_id                        type  \
# 0     2021-FYJTFP                 [ความสะอาด]
# 1     2021-CGPMUN        [น้ำท่วม, ร้องเรียน]
# 2     2021-7XATFA                     [สะพาน]
# 3     2021-DVEWYM              [น้ำท่วม, ถนน]
# 4     2021-4D9Y98                          []
# ...           ...                         ...
# 1367  2022-G8PE6C  [คลอง, สะพาน, ความปลอดภัย]
# 1368  2022-83GTYF             [จราจร, ต้นไม้]
# 1369  2022-6CHPLA   [ถนน, สะพาน, ความปลอดภัย]
# 1370  2022-FYYC2U                          []
# 1371  2022-FBACL9                       [ถนน]
#
#                                            organization  \
# 0                                            เขตบางซื่อ
# 1                          เขตประเวศ,ฝ่ายโยธา เขตประเวศ
# 2                                               เขตสาทร
# 3                      เขตลาดพร้าว,ฝ่ายโยธา เขตลาดพร้าว
# 4              เขตลาดพร้าว,การไฟฟ้านครหลวง เขตนวลจันทร์
# ...                                                 ...
# ...

# %%
df.dtypes
# Out:
# ticket_id                object
# type                     object
# organization             object
# comment                  object
# photo                    object
# photo_after              object
# address                  object
# subdistrict              object
# district                 object
# province                 object
# timestamp        datetime64[ns]
# state                    object
# star                    float64
# count_reopen              int64
# last_activity    datetime64[ns]
# longitude               float64
# latitude                float64
# dtype: object

# %%
df.to_csv("processed_data.csv", index=False)
